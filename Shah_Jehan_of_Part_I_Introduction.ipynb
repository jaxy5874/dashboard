# %% [markdown]
# <a href="https://colab.research.google.com/github/jaxy5874/dashboard/blob/main/Shah_Jehan_of_Part_I_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 1: Introduction to R

# %% [markdown]
# ## 1.1 Expression
#
# For example: numerical calculation

# %%
2.33+10
4.69*2/0.3
9.3+2.3/0.4
# Out:
# [1] 12.33
# [1] 31.26667
# [1] 15.05

# %%
#Exercise 1.1: Create one expression
9/2+(10)^2
# Out:
# [1] 104.5

# %% [markdown]
# ## 1.2 Creating new variables
#
# Variables are,in their simplest forms,like mathematical variables:they contain
# values.You can assign values using either = or <-.

# %%
a1=2.33+10
data=4.69*2/0.3

my_observation<-9.3+2.3/0.4

# %%
a1
data
my_observation
# Out:
# [1] 12.33
# [1] 31.26667
# [1] 15.05

# %%
#Exercise 1.2: Create new variable for exercise 1.1
t=9/2+(10)^2

# %% [markdown]
# ## 1.3 Data Types and Type Conversion

# %% [markdown]
# **Numeric and Character**

# %%
#value
height <- 160.6
breakfast <- "No"

# %%
#data type
is.numeric(height)
is.character(breakfast)
# Out:
# [1] TRUE
# [1] TRUE

# %%
# Converting type

height <- c("180", " 156 ", "166")
is.numeric(height)
# Out:
# [1] FALSE

# %%
height.1 <- as.numeric(height)
height.1
is.numeric(height.1)
# Out:
# [1] 180 156 166
# [1] TRUE

# %%
#Exercise 1.3
#change the data into numeric type

breakfastcost=c("10.60","6.80","3.20")
is.numeric(breakfastcost)
breakfastcost.1 = as.numeric(breakfastcost)
breakfastcost.1
is.numeric(breakfastcost.1)
# Out:
# [1] FALSE
# [1] 10.6  6.8  3.2
# [1] TRUE

# %% [markdown]
# ## 1.4 Vectors
# A vector is a basic data structure which plays an important role in R programming. In R, a sequence of elements which share the same data type is known as vector. A vector supports logical, integer, double, character, complex, or raw data type.

# %%
# Example
v1=c(30,50,100)
v2=c(45,66,29)

# %%
v1
v2
# Out:
# [1]  30  50 100
# [1] 45 66 29

# %%
#Aritmetic operation

p1=v1+v2
p1
# Out:
# [1]  75 116 129

# %%
#Exercise 1.4
#create 2 vectors for a1 and a2, then calculate a2-a1

a1 = c(3.4,6,5)
a2 = c(5,6.2,1.4)

b = a1 - a2
b
# Out:
# [1] -1.6 -0.2  3.6

# %% [markdown]
# ## 1.5 Matrices
#
# A matrix is a two dimensional data set with columns
# and rows.
#
# A column is a vertical representation of data, while a row is a horizontal representation of data.
#
# A matrix can be created with the matrix() function. Specify the nrow and ncol parameters to get the amount of rows and columns:

# %%
#Create Matrix
M <- matrix(c(3:14), nrow = 4, ncol = 3)
print(M)
# Out:
#      [,1] [,2] [,3]
# [1,]    3    7   11
# [2,]    4    8   12
# [3,]    5    9   13
# [4,]    6   10   14

# %%
# Elements are arranged sequentially by row.
M <- matrix(c(3:14), nrow = 4, byrow = TRUE)
print(M)
# Out:
#      [,1] [,2] [,3]
# [1,]    3    4    5
# [2,]    6    7    8
# [3,]    9   10   11
# [4,]   12   13   14

# %%
# Elements are arranged sequentially by column.
N <- matrix(c(3:14), nrow = 4, byrow = FALSE)
print(N)
# Out:
#      [,1] [,2] [,3]
# [1,]    3    7   11
# [2,]    4    8   12
# [3,]    5    9   13
# [4,]    6   10   14

# %%
# Define the column and row names.
rownames = c("row1", "row2", "row3", "row4")
colnames = c("col1", "col2", "col3")

P <- matrix(c(3:14), nrow = 4, byrow = TRUE, dimnames = list(rownames, colnames))
print(P)
# Out:
#      col1 col2 col3
# row1    3    4    5
# row2    6    7    8
# row3    9   10   11
# row4   12   13   14

# %% [markdown]
# ### 1.5.1 Extract the elements

# %%
#Extract the elements

#by row
M[3,]

#by column
N[,2]

#specify the location
P[2,2]
# Out:
# [1]  9 10 11
# [1]  7  8  9 10
# [1] 7

# %% [markdown]
# ### 1.5.2 Sum and average across the columns and rows
#
# function: *colSums(), rowSums(), colMeans() or rowMeans()*

# %%
print(N)
colSums(N)
# Out:
#      [,1] [,2] [,3]
# [1,]    3    7   11
# [2,]    4    8   12
# [3,]    5    9   13
# [4,]    6   10   14
# [1] 18 34 50

# %%
print(N)
rowSums(N)
# Out:
#      [,1] [,2] [,3]
# [1,]    3    7   11
# [2,]    4    8   12
# [3,]    5    9   13
# [4,]    6   10   14
# [1] 21 24 27 30

# %%
## Exercise 1.5 Use colMeans() or rowMeans() for M matrix
print(M)
colMeans(M)
rowMeans(M)
# Out:
#      [,1] [,2] [,3]
# [1,]    3    4    5
# [2,]    6    7    8
# [3,]    9   10   11
# [4,]   12   13   14
# [1] 7.5 8.5 9.5
# [1]  4  7 10 13

# %% [markdown]
# ## 1.6 Lists
# A list in R can contain many different data types inside it. A list is a collection of data which is ordered and changeable.
#
# To create a list, use the list() function:

# %%
# List of strings
L1 <- list("grape", "banana", "mango","papaya","guava")

# Print the list
L1

# %%
#Access Lists
L1[3]

# %%
#Change Item Value
L1 <- list("grape", "banana", "mango","papaya","guava")
L1[2] <- "blackcurrant"

# Print the updated list
L1

# %%
#Add List Items
L1 <- list("grape", "banana", "mango","papaya","guava")

L2<-append(L1, "orange")

L2

# %%
## Exercise 1.6
## Replace guava with rambutan and add jackfruit in L2

# %% [markdown]
# ## 1.7 Data Frames
#
# Data Frames are data displayed in a format as a table.
#
# Data Frames can have different types of data inside it. While the first column can be character, the second and third can be numeric or logical. However, each column should have the same type of data.
#
# Use the data.frame() function to create a data frame:

# %%
# Example
v1 = c(1, 2, 3)
v2 = c(3, 4, 5)
df = data.frame(v1, v2)
df

# %%
# Example
#Create a data frame
Data_Frame <- data.frame (
  Training = c("Strength", "Stamina", "Other"),
  Pulse = c(100, 150, 120),
  Duration = c(60, 30, 45)
)

# Print the data frame
Data_Frame

# %%
#Summarize the Data
summary(Data_Frame)

# %%
#Exercise 1.7: Create a data frame as depicted in Figure.

# %% [markdown]
# ![dataframe exercise.png](data:image/png;base64,...)

# %% [markdown]
# # Chapter 2: Data Transformation

# %% [markdown]
# ## 2.1 Data

# %%
# Create a sample data frame
df <- data.frame(id = c(1,2,3,4,5),
                 group = c("A","B","A","B","A"),
                 value = c(30,23,46,48,58))
df
# Out:
#   id group value
# 1 1  A     30
# 2 2  B     23
# 3 3  A     46
# 4 4  B     48
# 5 5  A     58

# %% [markdown]
# ## 2.2 Group_by

# %%
install.packages("tidyverse")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.1     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.3     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# Group by 'group' column and summarize the mean of 'value'
df %>%
  group_by(group) %>%
  summarize(mean_value = mean(value))
# Out:
#   group mean_value
# 1 A     44.66667
# 2 B     35.50000

# %%
library(dplyr)
# Create a sample data frame (re-defining df here to ensure it's a data.frame)
df <- data.frame(id = c(1,2,3,4,5),
                 group = c("A","B","A","B","A"),
                 value = c(30,23,46,48,58))
print(class(df))
df %>%
  group_by(group) %>%
  summarize(mean_value = mean(value))
# Out:
# [1] "data.frame"
#   group mean_value
# 1 A     44.66667
# 2 B     35.50000

# %%
# Filter rows where 'value' is greater than 45
df %>%
  filter(value > 45)
# Out:
#   id group value
# 1 3  A     46
# 2 4  B     48
# 3 5  A     58

# %% [markdown]
# ## 2.3 Arrange

# %%
# Arrange the data frame by 'value' in descending order
df %>%
  arrange(desc(value))
# Out:
#   id group value
# 1 5  A     58
# 2 4  B     48
# 3 3  A     46
# 4 1  A     30
# 5 2  B     23

# %%
# # Arrange the data frame by 'value' in descending order using AI
df %>%
  arrange(desc(value))
# Out:
#   id group value
# 1 5  A     58
# 2 4  B     48
# 3 3  A     46
# 4 1  A     30
# 5 2  B     23

# %%
# Arrange the data frame by 'value' in ascending order
df %>%
  arrange((value))

# %% [markdown]
# ## 2.4 Rename

# %%
# Rename the 'value' column to 'new_value'
df %>%
  rename(new_value = value)

# %% [markdown]
# ## 2.5 Mutate

# %%
# Mutate a new column 'squared_value' with the square of 'value'
df %>%
  mutate(squared_value = value^2)

# %% [markdown]
# ## 2.6 Summarize

# %%
# Summarize the total 'value' for each 'group'
df %>%
  group_by(group) %>%
  summarize(total_value = sum(value))

# %%
## Data
# Create a sample data frame
stock_prices <- data.frame(date = as.Date(c("2021-01-01", "2021-01-02", "2021-01-03", "2021-01-04", "2021-01-05")),
                           stock = c("AAPL", "AAPL", "GOOG", "GOOG", "AAPL"),
                           price = c(100, 110, 120, 130, 140),
                           volume = c(1000, 800, 600, 400, 200))
stock_prices

# %% [markdown]
# *   Group by 'stock' column and summarize the average price and volume
# *   Filter rows where the price is greater than 120
# *   Arrange the data frame by date in ascending order
# *   Rename the 'price' column to 'closing_price'
# *   Mutate a new column 'price_change' as the difference between current and previous price
# *   Summarize the total volume for each stock

# %%
##Group_by
# Group by 'stock' column and summarize the average price and volume
stock_prices %>%
  group_by(stock) %>%
  summarize(average_price = mean(price),
            average_volume = mean(volume))

# %%
##Filter
# Filter rows where the price is greater than 120
stock_prices %>%
  filter(price > 120)

# %%
## Arrange
# Arrange the data frame by date in ascending order
stock_prices %>%
  arrange(date)

# %%
## Rename
# Rename the 'price' column to 'closing_price'
stock_prices %>%
  rename(closing_price = price)

# %%
##Mutate
# Mutate a new column 'price_change' as the difference between current and previous price
stock_prices %>%
  mutate(price_change = price - lag(price))

# %%
## Summarize
# Summarize the total volume for each stock
stock_prices %>%
  group_by(stock) %>%
  summarize(total_volume = sum(volume))
